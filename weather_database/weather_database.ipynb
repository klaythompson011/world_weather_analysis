# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# create an empty list for holding the cities
cities = []

# use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# print the city count to confirm sufficient count
len(cities)
# Out:
# 760

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# import the requests library
import requests

# import the time library
import time

# import the datetime module from the datetime library
from datetime import datetime

# import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# create an empty list to hold weather data for each city
city_data = []

# print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# create counters and set them to 1
record_count = 1
set_count = 1

# loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # add 1 to the record count
    record_count += 1

    # run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                     "Lat": city_lat,
                     "Lng": city_lng,
                     "Max Temp": city_max_temp,
                     "Humidity": city_humidity,
                     "Cloudiness": city_clouds,
                     "Wind Speed": city_wind,
                     "Country": city_country,
                     "Current Description": city_description})
    
    # if an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavaratti
# Processing Record 2 of Set 1 | tuatapere
# Processing Record 3 of Set 1 | quang ngai
# Processing Record 4 of Set 1 | shelburne
# Processing Record 5 of Set 1 | saravan
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | yatou
# Processing Record 12 of Set 1 | ngaoundere
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | am timan
# Processing Record 15 of Set 1 | kieta
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | mahebourg
# Processing Record 20 of Set 1 | esperance
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | provideniya
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | yulara
# Processing Record 25 of Set 1 | kalemie
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | bella union
# Processing Record 28 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 1 | laguna
# Processing Record 30 of Set 1 | mehamn
# Processing Record 31 of Set 1 | ixtapa
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | nevelsk
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | cahabon
# Processing Record 39 of Set 1 | butaritari
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | khani
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | nanortalik
# Processing Record 45 of Set 1 | saint-augustin
# Processing Record 46 of Set 1 | bathsheba
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | saldanha
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | wilmington
# Processing Record 1 of Set 2 | tuktoyaktuk
# Processing Record 2 of Set 2 | lata
# Processing Record 3 of Set 2 | yeppoon
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | lephepe
# City not found. Skipping...
# Processing Record 7 of Set 2 | victoria
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | mitsamiouli
# Processing Record 10 of Set 2 | port lincoln
# Processing Record 11 of Set 2 | hilo
# Processing Record 12 of Set 2 | thompson
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | ostrovnoy
# Processing Record 15 of Set 2 | jacareacanga
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | anadyr
# Processing Record 18 of Set 2 | catuday
# Processing Record 19 of Set 2 | souillac
# Processing Record 20 of Set 2 | belmonte
# Processing Record 21 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 2 | kharitonovo
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | dalbandin
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | cockburn town
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | rikitea
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | bengkulu
# Processing Record 32 of Set 2 | palana
# Processing Record 33 of Set 2 | eisenberg
# Processing Record 34 of Set 2 | bukama
# Processing Record 35 of Set 2 | sorland
# Processing Record 36 of Set 2 | shimoda
# Processing Record 37 of Set 2 | samarai
# Processing Record 38 of Set 2 | kharabali
# Processing Record 39 of Set 2 | pisco
# Processing Record 40 of Set 2 | burnie
# Processing Record 41 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 2 | kenai
# Processing Record 43 of Set 2 | ahipara
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | codrington
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | mezen
# Processing Record 49 of Set 2 | prince albert
# Processing Record 50 of Set 2 | portland
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | natal
# Processing Record 3 of Set 3 | kapaa
# Processing Record 4 of Set 3 | sochaczew
# Processing Record 5 of Set 3 | marck
# Processing Record 6 of Set 3 | northam
# Processing Record 7 of Set 3 | camacha
# Processing Record 8 of Set 3 | yerbogachen
# Processing Record 9 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | uglyanets
# Processing Record 11 of Set 3 | tyshkivka
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | coahuayana
# Processing Record 14 of Set 3 | aswan
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | otofuke
# Processing Record 17 of Set 3 | cape town
# Processing Record 18 of Set 3 | karratha
# Processing Record 19 of Set 3 | progreso
# Processing Record 20 of Set 3 | mangrol
# Processing Record 21 of Set 3 | faanui
# Processing Record 22 of Set 3 | wajima
# Processing Record 23 of Set 3 | nikki
# Processing Record 24 of Set 3 | barrow
# Processing Record 25 of Set 3 | kaitangata
# Processing Record 26 of Set 3 | lorengau
# Processing Record 27 of Set 3 | derzhavinsk
# Processing Record 28 of Set 3 | pangnirtung
# Processing Record 29 of Set 3 | ahuimanu
# Processing Record 30 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 3 | saskylakh
# Processing Record 32 of Set 3 | darhan
# Processing Record 33 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 3 | bambanglipuro
# Processing Record 35 of Set 3 | najran
# Processing Record 36 of Set 3 | yakima
# Processing Record 37 of Set 3 | salalah
# Processing Record 38 of Set 3 | prince rupert
# Processing Record 39 of Set 3 | stralsund
# Processing Record 40 of Set 3 | alofi
# Processing Record 41 of Set 3 | hutchinson
# Processing Record 42 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 3 | dhidhdhoo
# Processing Record 44 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 3 | wukari
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | hofn
# Processing Record 48 of Set 3 | corowa
# Processing Record 49 of Set 3 | aguadilla
# Processing Record 50 of Set 3 | praia da vitoria
# Processing Record 1 of Set 4 | new norfolk
# Processing Record 2 of Set 4 | gurupi
# Processing Record 3 of Set 4 | saryg-sep
# Processing Record 4 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 4 | saint-philippe
# Processing Record 7 of Set 4 | hobyo
# Processing Record 8 of Set 4 | katsuura
# Processing Record 9 of Set 4 | kallithea
# Processing Record 10 of Set 4 | kabare
# Processing Record 11 of Set 4 | hasaki
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | saint-pierre
# Processing Record 16 of Set 4 | batemans bay
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | sarangani
# Processing Record 19 of Set 4 | hovd
# Processing Record 20 of Set 4 | tiksi
# Processing Record 21 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 4 | sorong
# Processing Record 23 of Set 4 | vao
# Processing Record 24 of Set 4 | eenhana
# Processing Record 25 of Set 4 | richards bay
# Processing Record 26 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 27 of Set 4 | padang
# Processing Record 28 of Set 4 | garowe
# Processing Record 29 of Set 4 | beloha
# Processing Record 30 of Set 4 | aquiraz
# Processing Record 31 of Set 4 | kanpur
# Processing Record 32 of Set 4 | santa rita
# Processing Record 33 of Set 4 | rozkishne
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | big rapids
# Processing Record 36 of Set 4 | pevek
# Processing Record 37 of Set 4 | mahibadhoo
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | norman wells
# Processing Record 40 of Set 4 | salinopolis
# Processing Record 41 of Set 4 | orlik
# Processing Record 42 of Set 4 | ladario
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | bjornevatn
# Processing Record 45 of Set 4 | cabo san lucas
# Processing Record 46 of Set 4 | grabouw
# Processing Record 47 of Set 4 | porto novo
# Processing Record 48 of Set 4 | macas
# Processing Record 49 of Set 4 | villa maria
# Processing Record 50 of Set 4 | cherskiy
# Processing Record 1 of Set 5 | sharlyk
# Processing Record 2 of Set 5 | bilibino
# Processing Record 3 of Set 5 | san cristobal
# Processing Record 4 of Set 5 | alekseyevsk
# Processing Record 5 of Set 5 | zhigansk
# Processing Record 6 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | sandusky
# Processing Record 8 of Set 5 | dingle
# Processing Record 9 of Set 5 | huarmey
# Processing Record 10 of Set 5 | ambulu
# Processing Record 11 of Set 5 | lang son
# Processing Record 12 of Set 5 | todos santos
# Processing Record 13 of Set 5 | severo-yeniseyskiy
# Processing Record 14 of Set 5 | khatanga
# Processing Record 15 of Set 5 | saint-paul
# Processing Record 16 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 17 of Set 5 | ardakan
# Processing Record 18 of Set 5 | beringovskiy
# Processing Record 19 of Set 5 | arraial do cabo
# Processing Record 20 of Set 5 | burica
# City not found. Skipping...
# Processing Record 21 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 5 | ada
# Processing Record 23 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 24 of Set 5 | torbay
# Processing Record 25 of Set 5 | roald
# Processing Record 26 of Set 5 | rafaela
# Processing Record 27 of Set 5 | adrar
# Processing Record 28 of Set 5 | tuy hoa
# Processing Record 29 of Set 5 | muzhi
# Processing Record 30 of Set 5 | juxian
# City not found. Skipping...
# Processing Record 31 of Set 5 | genteng
# Processing Record 32 of Set 5 | ngunguru
# Processing Record 33 of Set 5 | xinqing
# Processing Record 34 of Set 5 | isiolo
# Processing Record 35 of Set 5 | kupang
# Processing Record 36 of Set 5 | flinders
# Processing Record 37 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 5 | naze
# Processing Record 39 of Set 5 | wexford
# Processing Record 40 of Set 5 | steinkjer
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | arman
# Processing Record 43 of Set 5 | panguna
# Processing Record 44 of Set 5 | yumen
# Processing Record 45 of Set 5 | sylvania
# Processing Record 46 of Set 5 | tessalit
# Processing Record 47 of Set 5 | rongcheng
# Processing Record 48 of Set 5 | anicuns
# Processing Record 49 of Set 5 | saint george
# Processing Record 50 of Set 5 | panzhihua
# Processing Record 1 of Set 6 | atasu
# Processing Record 2 of Set 6 | ayan
# Processing Record 3 of Set 6 | maceio
# Processing Record 4 of Set 6 | birao
# Processing Record 5 of Set 6 | korla
# Processing Record 6 of Set 6 | faya
# Processing Record 7 of Set 6 | pathein
# Processing Record 8 of Set 6 | ishigaki
# Processing Record 9 of Set 6 | lagoa
# Processing Record 10 of Set 6 | egvekinot
# Processing Record 11 of Set 6 | mkokotoni
# Processing Record 12 of Set 6 | columbia
# Processing Record 13 of Set 6 | rio gallegos
# Processing Record 14 of Set 6 | lac du bonnet
# Processing Record 15 of Set 6 | komsomolskiy
# Processing Record 16 of Set 6 | goderich
# Processing Record 17 of Set 6 | ambon
# Processing Record 18 of Set 6 | tambura
# Processing Record 19 of Set 6 | ilhabela
# Processing Record 20 of Set 6 | port hardy
# Processing Record 21 of Set 6 | castro
# Processing Record 22 of Set 6 | sinnamary
# Processing Record 23 of Set 6 | kungurtug
# Processing Record 24 of Set 6 | mosquera
# Processing Record 25 of Set 6 | itumba
# Processing Record 26 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 6 | teguldet
# Processing Record 28 of Set 6 | pasighat
# Processing Record 29 of Set 6 | alice springs
# Processing Record 30 of Set 6 | constitucion
# Processing Record 31 of Set 6 | manga
# Processing Record 32 of Set 6 | havre-saint-pierre
# Processing Record 33 of Set 6 | kavieng
# Processing Record 34 of Set 6 | mwinilunga
# Processing Record 35 of Set 6 | makakilo city
# Processing Record 36 of Set 6 | varhaug
# Processing Record 37 of Set 6 | antofagasta
# Processing Record 38 of Set 6 | pangai
# Processing Record 39 of Set 6 | margate
# Processing Record 40 of Set 6 | buala
# Processing Record 41 of Set 6 | kencong
# Processing Record 42 of Set 6 | mooi river
# City not found. Skipping...
# Processing Record 43 of Set 6 | nieuw amsterdam
# Processing Record 44 of Set 6 | westerly
# Processing Record 45 of Set 6 | sistranda
# Processing Record 46 of Set 6 | raymondville
# Processing Record 47 of Set 6 | linhares
# Processing Record 48 of Set 6 | sao jose de piranhas
# Processing Record 49 of Set 6 | gimli
# Processing Record 50 of Set 6 | zhaoyuan
# Processing Record 1 of Set 7 | aripuana
# Processing Record 2 of Set 7 | kantilo
# Processing Record 3 of Set 7 | iqaluit
# Processing Record 4 of Set 7 | ilulissat
# Processing Record 5 of Set 7 | stromness
# Processing Record 6 of Set 7 | minsk
# Processing Record 7 of Set 7 | henties bay
# Processing Record 8 of Set 7 | eyl
# Processing Record 9 of Set 7 | black forest
# Processing Record 10 of Set 7 | samdari
# Processing Record 11 of Set 7 | bud
# Processing Record 12 of Set 7 | hobart
# Processing Record 13 of Set 7 | hay river
# Processing Record 14 of Set 7 | batticaloa
# Processing Record 15 of Set 7 | namtsy
# Processing Record 16 of Set 7 | chokurdakh
# Processing Record 17 of Set 7 | katherine
# Processing Record 18 of Set 7 | nouadhibou
# Processing Record 19 of Set 7 | opobo
# City not found. Skipping...
# Processing Record 20 of Set 7 | yangambi
# Processing Record 21 of Set 7 | gushikawa
# Processing Record 22 of Set 7 | oktyabrskiy
# Processing Record 23 of Set 7 | aklavik
# Processing Record 24 of Set 7 | malartic
# Processing Record 25 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | auki
# Processing Record 27 of Set 7 | rafraf
# Processing Record 28 of Set 7 | kaeo
# Processing Record 29 of Set 7 | valparaiso
# Processing Record 30 of Set 7 | quatre cocos
# Processing Record 31 of Set 7 | sala consilina
# Processing Record 32 of Set 7 | fairbanks
# Processing Record 33 of Set 7 | merauke
# Processing Record 34 of Set 7 | kyra
# Processing Record 35 of Set 7 | methven
# Processing Record 36 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 7 | neepawa
# Processing Record 38 of Set 7 | poum
# Processing Record 39 of Set 7 | arenapolis
# Processing Record 40 of Set 7 | san roque
# Processing Record 41 of Set 7 | vanimo
# Processing Record 42 of Set 7 | broome
# Processing Record 43 of Set 7 | prainha
# Processing Record 44 of Set 7 | sao domingos
# Processing Record 45 of Set 7 | babynino
# Processing Record 46 of Set 7 | arkadak
# Processing Record 47 of Set 7 | abu dhabi
# Processing Record 48 of Set 7 | la roda
# Processing Record 49 of Set 7 | chuy
# Processing Record 50 of Set 7 | huron
# Processing Record 1 of Set 8 | itarema
# Processing Record 2 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 8 | santa eulalia
# Processing Record 4 of Set 8 | jining
# Processing Record 5 of Set 8 | grindavik
# Processing Record 6 of Set 8 | umba
# Processing Record 7 of Set 8 | cidreira
# Processing Record 8 of Set 8 | poso
# Processing Record 9 of Set 8 | alyangula
# Processing Record 10 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 8 | muros
# Processing Record 12 of Set 8 | sur
# Processing Record 13 of Set 8 | geraldton
# Processing Record 14 of Set 8 | verkhozim
# Processing Record 15 of Set 8 | puerto carreno
# Processing Record 16 of Set 8 | gizo
# Processing Record 17 of Set 8 | riviere-du-loup
# Processing Record 18 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 19 of Set 8 | noumea
# Processing Record 20 of Set 8 | necochea
# Processing Record 21 of Set 8 | magaria
# Processing Record 22 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 8 | los llanos de aridane
# Processing Record 24 of Set 8 | shihezi
# Processing Record 25 of Set 8 | kedrovyy
# Processing Record 26 of Set 8 | shestakovo
# Processing Record 27 of Set 8 | bria
# Processing Record 28 of Set 8 | altay
# Processing Record 29 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 8 | helong
# Processing Record 31 of Set 8 | tecoanapa
# Processing Record 32 of Set 8 | normandin
# Processing Record 33 of Set 8 | tamandare
# Processing Record 34 of Set 8 | stornoway
# Processing Record 35 of Set 8 | otjimbingwe
# Processing Record 36 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 8 | kanniyakumari
# Processing Record 39 of Set 8 | houma
# Processing Record 40 of Set 8 | realeza
# Processing Record 41 of Set 8 | ban tak
# Processing Record 42 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 43 of Set 8 | barra patuca
# Processing Record 44 of Set 8 | marzuq
# Processing Record 45 of Set 8 | santa marta
# Processing Record 46 of Set 8 | salym
# Processing Record 47 of Set 8 | borba
# Processing Record 48 of Set 8 | tunkas
# Processing Record 49 of Set 8 | casa nova
# Processing Record 50 of Set 8 | baruun-urt
# Processing Record 1 of Set 9 | flin flon
# Processing Record 2 of Set 9 | fortuna
# Processing Record 3 of Set 9 | iquique
# Processing Record 4 of Set 9 | piet retief
# Processing Record 5 of Set 9 | marawi
# Processing Record 6 of Set 9 | elliot lake
# Processing Record 7 of Set 9 | soyo
# Processing Record 8 of Set 9 | moyale
# Processing Record 9 of Set 9 | macau
# Processing Record 10 of Set 9 | cooma
# Processing Record 11 of Set 9 | daru
# Processing Record 12 of Set 9 | rundu
# Processing Record 13 of Set 9 | stokmarknes
# Processing Record 14 of Set 9 | gangapur
# Processing Record 15 of Set 9 | dakar
# Processing Record 16 of Set 9 | dabola
# Processing Record 17 of Set 9 | marion
# Processing Record 18 of Set 9 | slonim
# Processing Record 19 of Set 9 | troitskoye
# Processing Record 20 of Set 9 | bajos de haina
# Processing Record 21 of Set 9 | olinda
# Processing Record 22 of Set 9 | aljezur
# Processing Record 23 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 9 | westport
# Processing Record 25 of Set 9 | kochki
# Processing Record 26 of Set 9 | zhezkazgan
# Processing Record 27 of Set 9 | armidale
# Processing Record 28 of Set 9 | takoradi
# Processing Record 29 of Set 9 | hobbs
# Processing Record 30 of Set 9 | aksu
# Processing Record 31 of Set 9 | davila
# Processing Record 32 of Set 9 | joensuu
# Processing Record 33 of Set 9 | lumeje
# Processing Record 34 of Set 9 | punto fijo
# Processing Record 35 of Set 9 | rapid valley
# Processing Record 36 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 9 | vanderhoof
# Processing Record 38 of Set 9 | nuuk
# Processing Record 39 of Set 9 | port blair
# Processing Record 40 of Set 9 | carballo
# Processing Record 41 of Set 9 | bereda
# Processing Record 42 of Set 9 | isangel
# Processing Record 43 of Set 9 | gamut
# Processing Record 44 of Set 9 | tadine
# Processing Record 45 of Set 9 | kampot
# Processing Record 46 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 9 | itaituba
# Processing Record 48 of Set 9 | brae
# Processing Record 49 of Set 9 | alihe
# Processing Record 50 of Set 9 | shingu
# Processing Record 1 of Set 10 | labuhan
# Processing Record 2 of Set 10 | redding
# Processing Record 3 of Set 10 | tiznit
# Processing Record 4 of Set 10 | ponta delgada
# Processing Record 5 of Set 10 | vostok
# Processing Record 6 of Set 10 | bowen
# Processing Record 7 of Set 10 | deputatskiy
# Processing Record 8 of Set 10 | yenangyaung
# Processing Record 9 of Set 10 | mikhaylovka
# Processing Record 10 of Set 10 | teguise
# Processing Record 11 of Set 10 | bafang
# Processing Record 12 of Set 10 | abu samrah
# Processing Record 13 of Set 10 | la brea
# Processing Record 14 of Set 10 | nioro
# Processing Record 15 of Set 10 | severo-kurilsk
# Processing Record 16 of Set 10 | yar-sale
# Processing Record 17 of Set 10 | marshfield
# Processing Record 18 of Set 10 | marsaxlokk
# Processing Record 19 of Set 10 | baykit
# Processing Record 20 of Set 10 | puerto leguizamo
# Processing Record 21 of Set 10 | kuito
# Processing Record 22 of Set 10 | kumylzhenskaya
# Processing Record 23 of Set 10 | caravelas
# Processing Record 24 of Set 10 | andros town
# Processing Record 25 of Set 10 | nome
# Processing Record 26 of Set 10 | hastings
# Processing Record 27 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 10 | mizan teferi
# Processing Record 29 of Set 10 | tokur
# Processing Record 30 of Set 10 | dongsheng
# Processing Record 31 of Set 10 | camopi
# Processing Record 32 of Set 10 | exeter
# Processing Record 33 of Set 10 | talnakh
# Processing Record 34 of Set 10 | clyde river
# Processing Record 35 of Set 10 | ewo
# Processing Record 36 of Set 10 | houston
# Processing Record 37 of Set 10 | hambantota
# Processing Record 38 of Set 10 | narodychi
# Processing Record 39 of Set 10 | tshikapa
# Processing Record 40 of Set 10 | wattegama
# Processing Record 41 of Set 10 | zemio
# Processing Record 42 of Set 10 | san quintin
# Processing Record 43 of Set 10 | reyes
# Processing Record 44 of Set 10 | griffith
# Processing Record 45 of Set 10 | kiunga
# Processing Record 46 of Set 10 | rumphi
# Processing Record 47 of Set 10 | rawson
# Processing Record 48 of Set 10 | hokitika
# Processing Record 49 of Set 10 | pacific grove
# Processing Record 50 of Set 10 | fort nelson
# Processing Record 1 of Set 11 | sao joao da barra
# Processing Record 2 of Set 11 | teteven
# Processing Record 3 of Set 11 | alta floresta
# Processing Record 4 of Set 11 | atar
# Processing Record 5 of Set 11 | chifeng
# Processing Record 6 of Set 11 | high level
# Processing Record 7 of Set 11 | tinskoy
# Processing Record 8 of Set 11 | pozo colorado
# Processing Record 9 of Set 11 | floriano
# Processing Record 10 of Set 11 | vaitape
# Processing Record 11 of Set 11 | sao jose da coroa grande
# Processing Record 12 of Set 11 | rtishchevo
# Processing Record 13 of Set 11 | prudy
# Processing Record 14 of Set 11 | roma
# Processing Record 15 of Set 11 | da nang
# Processing Record 16 of Set 11 | aksarka
# Processing Record 17 of Set 11 | sechura
# Processing Record 18 of Set 11 | banikoara
# Processing Record 19 of Set 11 | portree
# Processing Record 20 of Set 11 | darab
# Processing Record 21 of Set 11 | lasa
# Processing Record 22 of Set 11 | azul
# Processing Record 23 of Set 11 | saquena
# Processing Record 24 of Set 11 | makokou
# Processing Record 25 of Set 11 | manokwari
# Processing Record 26 of Set 11 | makungu
# Processing Record 27 of Set 11 | kjollefjord
# Processing Record 28 of Set 11 | okha
# Processing Record 29 of Set 11 | jos
# Processing Record 30 of Set 11 | olavarria
# Processing Record 31 of Set 11 | umm kaddadah
# Processing Record 32 of Set 11 | irpa irpa
# Processing Record 33 of Set 11 | eston
# Processing Record 34 of Set 11 | matagami
# Processing Record 35 of Set 11 | asfi
# Processing Record 36 of Set 11 | khromtau
# Processing Record 37 of Set 11 | sahuaripa
# Processing Record 38 of Set 11 | plettenberg bay
# Processing Record 39 of Set 11 | kamloops
# Processing Record 40 of Set 11 | ust-omchug
# Processing Record 41 of Set 11 | inta
# Processing Record 42 of Set 11 | port-gentil
# Processing Record 43 of Set 11 | havelock
# Processing Record 44 of Set 11 | sioux lookout
# Processing Record 45 of Set 11 | christchurch
# Processing Record 46 of Set 11 | kamaishi
# Processing Record 47 of Set 11 | luderitz
# Processing Record 48 of Set 11 | puerto del rosario
# Processing Record 49 of Set 11 | nuristan
# Processing Record 50 of Set 11 | coffs harbour
# Processing Record 1 of Set 12 | berlevag
# Processing Record 2 of Set 12 | cururupu
# Processing Record 3 of Set 12 | yenotayevka
# Processing Record 4 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 12 | greenville
# Processing Record 6 of Set 12 | kingisepp
# Processing Record 7 of Set 12 | tigre
# Processing Record 8 of Set 12 | torbat-e jam
# Processing Record 9 of Set 12 | bata
# Processing Record 10 of Set 12 | doha
# Processing Record 11 of Set 12 | malanje
# Processing Record 12 of Set 12 | poronaysk
# Processing Record 13 of Set 12 | arica
# Processing Record 14 of Set 12 | boende
# Processing Record 15 of Set 12 | bandarbeyla
# Processing Record 16 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 17 of Set 12 | mus
# Processing Record 18 of Set 12 | anori
# Processing Record 19 of Set 12 | vilani
# Processing Record 20 of Set 12 | camacari
# Processing Record 21 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 22 of Set 12 | reconquista
# Processing Record 23 of Set 12 | shatsk
# Processing Record 24 of Set 12 | yaan
# Processing Record 25 of Set 12 | afua
# Processing Record 26 of Set 12 | acapulco
# Processing Record 27 of Set 12 | vestmannaeyjar
# Processing Record 28 of Set 12 | canico
# Processing Record 29 of Set 12 | cayenne
# Processing Record 30 of Set 12 | arriana
# Processing Record 31 of Set 12 | oncesti
# Processing Record 32 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 12 | biskamzha
# Processing Record 34 of Set 12 | kichmengskiy gorodok
# Processing Record 35 of Set 12 | harper
# Processing Record 36 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 12 | ampanihy
# Processing Record 38 of Set 12 | amalapuram
# Processing Record 39 of Set 12 | frolovo
# Processing Record 40 of Set 12 | eureka
# Processing Record 41 of Set 12 | lyaskelya
# Processing Record 42 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 43 of Set 12 | kloulklubed
# Processing Record 44 of Set 12 | ugoofaaru
# Processing Record 45 of Set 12 | angoche
# Processing Record 46 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 12 | haimen
# Processing Record 48 of Set 12 | ranong
# Processing Record 49 of Set 12 | tranas
# Processing Record 50 of Set 12 | elizabeth city
# Processing Record 1 of Set 13 | paracuru
# Processing Record 2 of Set 13 | kemijarvi
# Processing Record 3 of Set 13 | morros
# Processing Record 4 of Set 13 | sirkali
# City not found. Skipping...
# Processing Record 5 of Set 13 | sompeta
# Processing Record 6 of Set 13 | chihuahua
# Processing Record 7 of Set 13 | uglovka
# Processing Record 8 of Set 13 | ancud
# Processing Record 9 of Set 13 | kokopo
# Processing Record 10 of Set 13 | husavik
# Processing Record 11 of Set 13 | kathmandu
# Processing Record 12 of Set 13 | ambovombe
# Processing Record 13 of Set 13 | tignere
# Processing Record 14 of Set 13 | halifax
# Processing Record 15 of Set 13 | zyryanka
# Processing Record 16 of Set 13 | mahabad
# Processing Record 17 of Set 13 | narsaq
# Processing Record 18 of Set 13 | gat
# Processing Record 19 of Set 13 | bonavista
# Processing Record 20 of Set 13 | taman
# Processing Record 21 of Set 13 | gogrial
# Processing Record 22 of Set 13 | kargasok
# Processing Record 23 of Set 13 | kodala
# Processing Record 24 of Set 13 | isla vista
# Processing Record 25 of Set 13 | angoram
# Processing Record 26 of Set 13 | chumikan
# Processing Record 27 of Set 13 | damghan
# Processing Record 28 of Set 13 | bassar
# Processing Record 29 of Set 13 | awbari
# Processing Record 30 of Set 13 | sola
# Processing Record 31 of Set 13 | buta
# Processing Record 32 of Set 13 | isla aguada
# Processing Record 33 of Set 13 | surt
# Processing Record 34 of Set 13 | skjervoy
# Processing Record 35 of Set 13 | mundo nuevo
# Processing Record 36 of Set 13 | churapcha
# Processing Record 37 of Set 13 | tigil
# Processing Record 38 of Set 13 | maamba
# Processing Record 39 of Set 13 | beloeil
# Processing Record 40 of Set 13 | susanville
# Processing Record 41 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 42 of Set 13 | great yarmouth
# Processing Record 43 of Set 13 | palmer
# Processing Record 44 of Set 13 | vengerovo
# Processing Record 45 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 46 of Set 13 | pedasi
# Processing Record 47 of Set 13 | sakata
# Processing Record 48 of Set 13 | ola
# Processing Record 49 of Set 13 | monte azul
# Processing Record 50 of Set 13 | dmitriyevka
# Processing Record 1 of Set 14 | macklin
# Processing Record 2 of Set 14 | taoudenni
# Processing Record 3 of Set 14 | uhlove
# Processing Record 4 of Set 14 | mackay
# Processing Record 5 of Set 14 | vestmanna
# Processing Record 6 of Set 14 | honningsvag
# Processing Record 7 of Set 14 | pingyin
# Processing Record 8 of Set 14 | coos bay
# Processing Record 9 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 14 | ishim
# Processing Record 11 of Set 14 | colares
# Processing Record 12 of Set 14 | waddan
# Processing Record 13 of Set 14 | tamayo
# Processing Record 14 of Set 14 | vila velha
# Processing Record 15 of Set 14 | nefteyugansk
# Processing Record 16 of Set 14 | wanaka
# Processing Record 17 of Set 14 | celestun
# Processing Record 18 of Set 14 | kingsville
# Processing Record 19 of Set 14 | magdagachi
# Processing Record 20 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 14 | marystown
# Processing Record 22 of Set 14 | pemangkat
# Processing Record 23 of Set 14 | neokhorion
# Processing Record 24 of Set 14 | bilma
# Processing Record 25 of Set 14 | great bend
# Processing Record 26 of Set 14 | chapais
# Processing Record 27 of Set 14 | derazhnya
# Processing Record 28 of Set 14 | magan
# Processing Record 29 of Set 14 | buraydah
# Processing Record 30 of Set 14 | tighina
# Processing Record 31 of Set 14 | clarence town
# Processing Record 32 of Set 14 | half moon bay
# Processing Record 33 of Set 14 | bourail
# Processing Record 34 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 35 of Set 14 | ketchikan
# Processing Record 36 of Set 14 | qingdao
# Processing Record 37 of Set 14 | soledad
# Processing Record 38 of Set 14 | mayachnyy
# Processing Record 39 of Set 14 | marfino
# Processing Record 40 of Set 14 | zhanaozen
# Processing Record 41 of Set 14 | ostersund
# Processing Record 42 of Set 14 | vrangel
# Processing Record 43 of Set 14 | marang
# Processing Record 44 of Set 14 | clinton
# Processing Record 45 of Set 14 | inuvik
# Processing Record 46 of Set 14 | montemor-o-novo
# Processing Record 47 of Set 14 | temir
# Processing Record 48 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 14 | kargapolye
# City not found. Skipping...
# Processing Record 50 of Set 14 | kahului
# Processing Record 1 of Set 15 | amuntai
# Processing Record 2 of Set 15 | saint-georges
# Processing Record 3 of Set 15 | sembakung
# Processing Record 4 of Set 15 | hailar
# Processing Record 5 of Set 15 | yabrud
# Processing Record 6 of Set 15 | aksay
# Processing Record 7 of Set 15 | kununurra
# Processing Record 8 of Set 15 | sal rei
# Processing Record 9 of Set 15 | spearfish
# Processing Record 10 of Set 15 | basco
# Processing Record 11 of Set 15 | chaplynka
# Processing Record 12 of Set 15 | razumnoye
# Processing Record 13 of Set 15 | aloleng
# Processing Record 14 of Set 15 | mitu
# Processing Record 15 of Set 15 | imbituba
# Processing Record 16 of Set 15 | havoysund
# Processing Record 17 of Set 15 | huangzhai
# Processing Record 18 of Set 15 | vila franca do campo
# Processing Record 19 of Set 15 | svetlaya
# Processing Record 20 of Set 15 | deh rawud
# City not found. Skipping...
# Processing Record 21 of Set 15 | ginir
# Processing Record 22 of Set 15 | colquiri
# Processing Record 23 of Set 15 | san antonio
# Processing Record 24 of Set 15 | apache junction
# Processing Record 25 of Set 15 | ust-kulom
# Processing Record 26 of Set 15 | boa vista
# Processing Record 27 of Set 15 | labytnangi
# Processing Record 28 of Set 15 | nemuro
# Processing Record 29 of Set 15 | santiago
# Processing Record 30 of Set 15 | marquette
# Processing Record 31 of Set 15 | fuling
# Processing Record 32 of Set 15 | don sak
# Processing Record 33 of Set 15 | asau
# Processing Record 34 of Set 15 | belyy yar
# Processing Record 35 of Set 15 | salatrucu
# Processing Record 36 of Set 15 | kazanka
# Processing Record 37 of Set 15 | honiara
# Processing Record 38 of Set 15 | puerto ayacucho
# Processing Record 39 of Set 15 | stavern
# Processing Record 40 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 15 | bulgan
# Processing Record 42 of Set 15 | nabire
# Processing Record 43 of Set 15 | tumpat
# Processing Record 44 of Set 15 | chicama
# Processing Record 45 of Set 15 | maniwaki
# Processing Record 46 of Set 15 | makung
# City not found. Skipping...
# Processing Record 47 of Set 15 | gilazi
# City not found. Skipping...
# Processing Record 48 of Set 15 | haines junction
# Processing Record 49 of Set 15 | ust-maya
# Processing Record 50 of Set 15 | champerico
# Processing Record 1 of Set 16 | kihei
# Processing Record 2 of Set 16 | glenwood springs
# Processing Record 3 of Set 16 | rosario oeste
# Processing Record 4 of Set 16 | klisura
# Processing Record 5 of Set 16 | nizhniy odes
# Processing Record 6 of Set 16 | irklievskaya
# City not found. Skipping...
# Processing Record 7 of Set 16 | zhangye
# Processing Record 8 of Set 16 | piotrkow trybunalski
# Processing Record 9 of Set 16 | kemise
# Processing Record 10 of Set 16 | kolondieba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kavaratti  10.5669   72.6420     82.69        69          26
# 1        Tuatapere -46.1333  167.6833     52.68        97         100
# 2       Quang Ngai  15.1167  108.8000     74.97        93           6
# 3        Shelburne  44.0787  -80.2041     28.76        83          87
# 4          Saravan  39.7196   45.6483     39.49        83          98
# 5           Albany  42.6001  -73.9662     41.95        66          84
# 6           Bethel  41.3712  -73.4140     44.02        61          75
# 7        Busselton -33.6500  115.3333     52.48        85          70
# 8  Bambous Virieux -20.3428   57.7575     71.85        60          20
# 9          Qaanaaq  77.4840  -69.3632    -17.00        77          11
#
#    Wind Speed Country Current Description
# 0        3.40      IN    scattered clouds
# 1        3.65      NZ          light rain
# 2        3.51      VN           clear sky
# 3       10.27      CA     overcast clouds
# 4        1.95      AM     overcast clouds
# 5        5.01      US       broken clouds
# 6       13.80      US       broken clouds
# 7       11.03      AU       broken clouds
# 8        3.44      MU          few clouds
# 9        8.37      GL          few clouds

# %%
# display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# display sample data
city_data_df
# Out:
#                      City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Kavaratti      IN  10.5669   72.6420     82.69        69
# 1               Tuatapere      NZ -46.1333  167.6833     52.68        97
# 2              Quang Ngai      VN  15.1167  108.8000     74.97        93
# 3               Shelburne      CA  44.0787  -80.2041     28.76        83
# 4                 Saravan      AM  39.7196   45.6483     39.49        83
# ..                    ...     ...      ...       ...       ...       ...
# 692          Nizhniy Odes      RU  63.6445   54.8560     -0.02        94
# 693               Zhangye      CN  38.9342  100.4517     30.85        38
# 694  Piotrkow Trybunalski      PL  51.4055   19.7032     32.11        10
# 695                Kemise      ET  10.7167   39.8667     65.43        47
# 696            Kolondieba      ML  11.0882   -6.8926     90.50        14
#
#      Cloudiness  Wind Speed Current Description
# 0            26        3.40    scattered clouds
# 1           100        3.65          light rain
# 2             6        3.51           clear sky
# 3            87       10.27     overcast clouds
# 4            98        1.95     overcast clouds
# ..          ...         ...                 ...
# 692          72        6.44       broken clouds
# 693          29        1.70    scattered clouds
# 694          38        7.96    scattered clouds
# 695           7        1.86           clear sky
# 696          87        7.07     overcast clouds
#
# [697 rows x 9 columns]

# %%
# display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# set the output file name
output_data_file = "../weather_database/weatherpy_database.csv"

# export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
